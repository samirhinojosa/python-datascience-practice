# %%
import pandas as pd

df = pd.read_csv("../datasets/avocado.csv")
df["Date"] = pd.to_datetime(df["Date"])
albany_df = df[ df["region"] == "Albany" ]
albany_df.set_index("Date", inplace=True) 
albany_df = albany_df.sort_index(ascending=False)
albany_df["AveragePrice"].plot()

# %%
albany_df.index
# Out:
# DatetimeIndex(['2018-03-25', '2018-03-25', '2018-03-18', '2018-03-18',
#                '2018-03-11', '2018-03-11', '2018-03-04', '2018-03-04',
#                '2018-02-25', '2018-02-25',
#                ...
#                '2015-02-01', '2015-02-01', '2015-01-25', '2015-01-25',
#                '2015-01-18', '2015-01-18', '2015-01-11', '2015-01-11',
#                '2015-01-04', '2015-01-04'],
#               dtype='datetime64[ns]', name='Date', length=338, freq=None)

# %%
albany_df["AveragePrice"].rolling(25).mean().plot()

# %%
albany_df.head(50)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# Date
# 2018-03-25           0          1.71       2321.82     42.95     272.41
# 2018-03-25           0          1.57     149396.50  16361.69  109045.03
# 2018-03-18           1          1.35     105304.65  13234.86   61037.58
# 2018-03-18           1          1.66       3154.45    275.89     297.96
# 2018-03-11           2          1.68       2570.52    131.67     229.56
# 2018-03-11           2          1.12     144648.75  15823.35  110950.68
# 2018-03-04           3          1.48       3851.30    311.55     296.77
# 2018-03-04           3          1.08     139520.60  12002.12  105069.57
# 2018-02-25           4          1.56       5356.63    816.56     532.59
# 2018-02-25           4          1.28     104278.89  10368.77   59723.32
# 2018-02-18           5          1.43       7566.17   4314.30     251.85
# 2018-02-18           5          1.43      85630.24   5499.73   61661.76
# 2018-02-11           6          1.43       3817.93     59.18     289.85
# 2018-02-11           6          1.45     121804.36   8183.48   95548.47
# 2018-02-04           7          1.52       4124.96    118.38     420.36
# 2018-02-04           7          1.03     216738.47   7625.65  195725.06
# 2018-01-28           8          1.32       6987.56    433.66     374.96
# 2018-01-28           8          1.57      93625.03   3101.17   74627.23
# 2018-01-21           9          1.69     135196.35   3133.37  116520.88
# 2018-01-21           9          1.54       3346.54     14.67     253.01
# 2018-01-14          10          1.42      95246.38   2897.41   76570.67
# 2018-01-14          10          1.47       4140.95      7.30     301.87
# 2018-01-07          11          1.13      98540.22   2940.63   76192.61
# 2018-01-07          11          1.54       4816.90     43.51     412.17
# 2017-12-31           0          1.46       3463.85     18.12     198.16
# 2017-12-31           0          1.47     113514.42   2622.70  101135.53
# 2017-12-24           1          1.45      77039.09   2811.71   58592.23
# 2017-12-24           1          1.58       3694.13     31.68     327.39
# 2017-12-17           2          1.43      70677.56   2578.95   50811.52
# 2017-12-17           2          1.43       3513.77     37.46     209.30
# 2017-12-10           3          1.45       3779.98     18.04     262.14
# 2017-12-10           3          1.29      92325.53   3220.05   75147.56
# 2017-12-03           4          1.44       3577.04    118.55     306.55
# 2017-12-03           4          1.39     139970.00   3772.00  126551.00
# 2017-11-26           5          1.50      62977.00   2413.00   49076.00
# 2017-11-26           5          1.57       2841.29     27.75     182.15
# 2017-11-19           6          1.75       2506.38      0.00     252.98
# 2017-11-19           6          1.65      97273.00   2695.00   80596.00
#                '2015-01-04', '2015-01-04'],
#               dtype='datetime64[ns]', name='Date', length=338, freq=None)

# %%
albany_df["price25ma"] = albany_df["AveragePrice"].rolling(25).mean()

# %%
albany_df.head(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# Date
# 2018-03-25           0          1.71       2321.82     42.95     272.41
# 2018-03-25           0          1.57     149396.50  16361.69  109045.03
# 2018-03-18           1          1.35     105304.65  13234.86   61037.58
#
#              4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2018-03-25   0.00     2006.46     1996.46       10.00          0.0
# 2018-03-25  65.45    23924.33    19273.80     4270.53        380.0
# 2018-03-18  55.00    30977.21    26755.90     3721.31        500.0
#
#                     type  year  region  price25ma
# Date
# 2018-03-25       organic  2018  Albany        NaN
# 2018-03-25  conventional  2018  Albany        NaN
# 2018-03-18  conventional  2018  Albany        NaN

# %%
albany_df.tail(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225  4770  \
# Date
# 2015-01-11          50          1.77       1182.56    39.00    305.12   0.0
# 2015-01-04          51          1.22      40873.28  2819.50  28287.42  49.9
# 2015-01-04          51          1.79       1373.95    57.42    153.88   0.0
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-01-11      838.44      838.44        0.00          0.0       organic
# 2015-01-04     9716.46     9186.93      529.53          0.0  conventional
# 2015-01-04     1162.65     1162.65        0.00          0.0       organic
#
#             year  region  price25ma
# Date
# 2015-01-11  2015  Albany     1.4636
# 2015-01-04  2015  Albany     1.4352
# 2015-01-04  2015  Albany     1.4296

# %%
#making copy to avoid SettingWithCopyWarning
albany_df = df.copy()[df["region"] == "Albany"]
albany_df.set_index("Date", inplace=True)
albany_df.sort_index(inplace=True)
albany_df["price25ma"] = albany_df["AveragePrice"].rolling(25).mean()

# %%
list(set(df["region"].values.tolist()))
# Out:
# ['BaltimoreWashington',
#  'Midsouth',
#  'Roanoke',
#  'SouthCarolina',
#  'Atlanta',
#  'NewOrleansMobile',
#  'Spokane',
#  'TotalUS',
#  'Seattle',
#  'Sacramento',
#  'Boston',
#  'LasVegas',
#  'Albany',
#  'Tampa',
#  'CincinnatiDayton',
#  'Portland',
#  'Charlotte',
#  'HartfordSpringfield',
#  'Orlando',
#  'NewYork',
#  'SanFrancisco',
#  'Northeast',
#  'PhoenixTucson',
#  'RichmondNorfolk',
#  'West',
#  'Pittsburgh',
#  'Indianapolis',
#  'DallasFtWorth',
#  'California',
#  'HarrisburgScranton',
#  'LosAngeles',
#  'RaleighGreensboro',
#  'SouthCentral',
#  'Philadelphia',
#  'GrandRapids',
#  'Plains',
#  'Syracuse',
#  'Louisville',
#  'Nashville',
#  'Chicago',
#  'Southeast',
#  'Jacksonville',
#  'Detroit',
#  'NorthernNewEngland',
#  'StLouis',
#  'WestTexNewMexico',
#  'MiamiFtLauderdale',
#  'BuffaloRochester',
#  'SanDiego',
#  'Denver',
#  'Boise',
#  'GreatLakes',
#  'Houston',
#  'Columbus']

# %%
df["region"].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
""" graph_df = pd.DataFrame()

for region in df["region"].unique()[:16]:
    print(region)
    region_df = df.copy()[df["region"] == region]
    region_df.set_index("Date", inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f'{region}_price25ma'] = region_df["AveragePrice"].rolling(25).mean()

    if graph_df.empty:
        graph_df = region_df[[f'{region}_price25ma']]
    else:
        graph_df = graph_df.join(region_df[f'{region}_price25ma']) """
# Out:
# ' graph_df = pd.DataFrame()\n\nfor region in df["region"].unique()[:16]:\n    print(region)\n    region_df = df.copy()[df["region"] == region]\n    region_df.set_index("Date", inplace=True)\n    region_df.sort_index(inplace=True)\n    region_df[f\'{region}_price25ma\'] = region_df["AveragePrice"].rolling(25).mean()\n\n    if graph_df.empty:\n        graph_df = region_df[[f\'{region}_price25ma\']]\n    else:\n        graph_df = graph_df.join(region_df[f\'{region}_price25ma\']) '

# %%
df.tail(3)
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046     4225  \
# 18246           9 2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
df["type"].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
import pandas as pd 

df = pd.read_csv("../datasets/avocado.csv")
df = df.copy()[df["type"] == "organic"]
df["Date"] = pd.to_datetime(df["Date"])

df.sort_values(by="Date", ascending=True, inplace=True)

graph_df = pd.DataFrame()

for region in df["region"].unique():
    print(region)
    region_df = df.copy()[df["region"] == region]
    region_df.set_index("Date", inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f'{region}_price25ma'] = region_df["AveragePrice"].rolling(25).mean()

    if graph_df.empty:
        graph_df = region_df[[f'{region}_price25ma']]
    else:
        graph_df = graph_df.join(region_df[f'{region}_price25ma'])

graph_df.tail()
# Out:
# California
# LasVegas
# PhoenixTucson
# BuffaloRochester
# Spokane
# LosAngeles
# Philadelphia
# Boston
# StLouis
# Louisville
# Orlando
# Southeast
# Boise
# MiamiFtLauderdale
# NorthernNewEngland
# BaltimoreWashington
# Midsouth
# Tampa
# West
# Northeast
# Atlanta
# Nashville
# TotalUS
# Syracuse
# WestTexNewMexico
# Jacksonville
# Charlotte
# Sacramento
# GrandRapids
# Roanoke
# Denver
# SanDiego
# GreatLakes
# RichmondNorfolk
# DallasFtWorth
# SanFrancisco
# HarrisburgScranton
# Pittsburgh
# RaleighGreensboro
# Seattle
# HartfordSpringfield
# Portland
# CincinnatiDayton
# SouthCarolina
# Houston
# Chicago
# Plains
# Indianapolis
# SouthCentral
# Columbus
# Albany
# Detroit
# NewOrleansMobile
# NewYork
#             California_price25ma  LasVegas_price25ma  PhoenixTucson_price25ma  \
# Date
# 2018-02-25                1.9128              1.9120                   1.7468
# 2018-03-04                1.8876              1.8748                   1.7404
# 2018-03-11                1.8636              1.8440                   1.7324
# 2018-03-18                1.8516              1.8204                   1.7216
# 2018-03-25                1.8364              1.7968                   1.7104
#
#             BuffaloRochester_price25ma  Spokane_price25ma  \
# Date
# 2018-02-25                      1.2912             2.1544
# 2018-03-04                      1.2744             2.1040
# 2018-03-11                      1.2652             2.0552
# 2018-03-18                      1.2560             2.0012
# 2018-03-25                      1.2416             1.9496
#
#             LosAngeles_price25ma  Philadelphia_price25ma  Boston_price25ma  \
# Date
# 2018-02-25                1.9024                  1.6324            1.7636
# 2018-03-04                1.8656                  1.6260            1.7708
# 2018-03-11                1.8284                  1.6300            1.7824
# 2018-03-18                1.8160                  1.6304            1.7932
# 2018-03-25                1.8016                  1.6256            1.7984
#
#             StLouis_price25ma  Louisville_price25ma  ...  Houston_price25ma  \
# Date                                                 ...
# 2018-02-25             1.9240                1.7044  ...             1.6132
# 2018-03-04             1.8868                1.6816  ...             1.5960
# 2018-03-11             1.8468                1.6508  ...             1.5696
# 2018-03-18             1.8192                1.6176  ...             1.5360
# 2018-03-25             1.7976                1.5844  ...             1.5128
#
#             Chicago_price25ma  Plains_price25ma  Indianapolis_price25ma  \
# Date
# 2018-02-25             1.8160            1.8116                  1.4928
# 2018-03-04             1.8024            1.7900                  1.4744
# 2018-03-11             1.7836            1.7672                  1.4540
# 2018-03-18             1.7732            1.7452                  1.4320
# 2018-03-25             1.7672            1.7232                  1.4160
#
#             SouthCentral_price25ma  Columbus_price25ma  Albany_price25ma  \
# Date
# 2018-02-25                  1.5728              1.6064            1.5112
# 2018-03-04                  1.5592              1.5804            1.4992
# 2018-03-11                  1.5400              1.5496            1.5044
# 2018-03-18                  1.5204              1.5088            1.5140
# 2018-03-25                  1.5072              1.4848            1.5188
#
#             Detroit_price25ma  NewOrleansMobile_price25ma  NewYork_price25ma
# Date
# 2018-02-25             1.4980                      1.5384             1.9308
# 2018-03-04             1.4692                      1.5288             1.9156
# 2018-03-11             1.4444                      1.5076             1.9092
# 2018-03-18             1.4092                      1.4860             1.8948
# 2018-03-25             1.3964                      1.4616             1.8876
#
# [5 rows x 54 columns]

# %%
graph_df.plot(figsize=(8, 5), legend=False)

# %%
graph_df.dropna().plot(figsize=(8, 5), legend=False)
